# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
mov=pd.read_csv(r'C:\Users\MR ACTIVATOR\Desktop\movies analysis\mov')

# %%
mov.head()
# Out:
#                      Title       Budget        ID Original Language  \
# 0                 Baywatch   69000000.0  339846.0                en
# 1                 The Wall          0.0  405775.0                en
# 2                   Gifted    7000000.0  400928.0                en
# 3          The Spacewalker    7075038.0  440642.0                ru
# 4  The Fate of the Furious  250000000.0  337339.0                en
#
#    Popularity Release Date       Revenue  Runtime  Vote Average  Vote Count
# 0   35.637691   05/12/2017  1.778568e+08    116.0           6.1      1829.0
# 1   15.597500   05/12/2017  1.803009e+06     89.0           6.1       117.0
# 2   16.025911   04/12/2017  3.746104e+07    101.0           7.7       549.0
# 3   10.181000   04/12/2017  9.868942e+06    140.0           7.4        20.0
# 4   48.573287   04/12/2017  1.238765e+09    136.0           6.8      3803.0

# %%
mov.describe()
# Out:
#              Budget             ID   Popularity       Revenue      Runtime  \
# count  4.535000e+03    4535.000000  4535.000000  4.535000e+03  4532.000000
# mean   2.865935e+07   96240.325028     9.311619  8.266938e+07   107.489629
# std    4.296899e+07  115101.300157    14.733265  1.700826e+08    21.082818
# min    0.000000e+00      12.000000     0.001272  1.000000e+00     0.000000
# 25%    5.250000e+01   11055.000000     4.666667  1.749329e+06    94.000000
# 50%    1.200000e+07   42399.000000     7.825072  1.912540e+07   104.000000
# 75%    3.700000e+07  153338.000000    11.261433  8.526087e+07   118.000000
# max    3.800000e+08  443319.000000   547.488298  2.787965e+09   338.000000
#
#        Vote Average    Vote Count
# count   4535.000000   4535.000000
# mean       6.186218    699.371555
# std        0.988983   1257.936544
# min        0.000000      0.000000
# 25%        5.700000     58.500000
# 50%        6.200000    232.000000
# 75%        6.800000    730.000000
# ...

# %%
mov.isnull()
# Out:
#       Title  Budget     ID  Original Language  Popularity  Release Date  \
# 0     False   False  False              False       False         False
# 1     False   False  False              False       False         False
# 2     False   False  False              False       False         False
# 3     False   False  False              False       False         False
# 4     False   False  False              False       False         False
# ...     ...     ...    ...                ...         ...           ...
# 4531  False   False  False              False       False         False
# 4532  False   False  False              False       False         False
# 4533  False   False  False              False       False         False
# 4534  False   False  False              False       False         False
# 4535   True    True   True               True        True          True
#
#       Revenue  Runtime  Vote Average  Vote Count
# 0       False    False         False       False
# ...

# %%
mov.drop_duplicates()
# Out:
#                                           Title       Budget        ID  \
# 0                                      Baywatch   69000000.0  339846.0
# 1                                      The Wall          0.0  405775.0
# 2                                        Gifted    7000000.0  400928.0
# 3                               The Spacewalker    7075038.0  440642.0
# 4                       The Fate of the Furious  250000000.0  337339.0
# ...                                         ...          ...       ...
# 4531                                     Snatch   10000000.0     107.0
# 4532                                  Gladiator  103000000.0      98.0
# 4533                                  3 Strikes    6000000.0   47816.0
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000.0   22597.0
# 4535                                        NaN          NaN       NaN
#
#      Original Language  Popularity Release Date       Revenue  Runtime  \
# ...

# %%
mov.dropna()
# Out:
#                                           Title       Budget        ID  \
# 0                                      Baywatch   69000000.0  339846.0
# 1                                      The Wall          0.0  405775.0
# 2                                        Gifted    7000000.0  400928.0
# 3                               The Spacewalker    7075038.0  440642.0
# 4                       The Fate of the Furious  250000000.0  337339.0
# ...                                         ...          ...       ...
# 4530                        Highlander: Endgame   25000000.0   12211.0
# 4531                                     Snatch   10000000.0     107.0
# 4532                                  Gladiator  103000000.0      98.0
# 4533                                  3 Strikes    6000000.0   47816.0
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000.0   22597.0
#
#      Original Language  Popularity Release Date       Revenue  Runtime  \
# ...

# %%
mov.shape
# Out:
# (4536, 10)

# %%
mov.dtypes
# Out:
# Title                 object
# Budget               float64
# ID                   float64
# Original Language     object
# Popularity           float64
# Release Date          object
# Revenue              float64
# Runtime              float64
# Vote Average         float64
# Vote Count           float64
# dtype: object

# %%
mov.groupby(['Popularity']).sum()
# Out:
#                                    Title       Budget        ID  \
# Popularity
# 0.001272          Live Nude Girls Unite!          0.0   99006.0
# 0.002354    Beyond the Gates of Splendor          0.0   61340.0
# 0.003305           The Grace Lee Project          0.0  185158.0
# 0.003568                  95 Miles to Go          0.0   79163.0
# 0.003647             Chaahat Ek Nasha...          0.0  362812.0
# ...                                  ...          ...       ...
# 213.849907                    Big Hero 6  165000000.0  177572.0
# 228.032744                   Baby Driver   34000000.0  339403.0
# 287.253654          Beauty and the Beast  160000000.0  321612.0
# 294.337037                  Wonder Woman  149000000.0  297762.0
# 547.488298                       Minions   74000000.0  211672.0
#
#            Original Language Release Date       Revenue  Runtime  \
# Popularity
# 0.001272                  en   10/06/2000  4.875200e+04     75.0
# ...

# %%
sns.pairplot(mov)
sns.set_palette('husl')
